# %% [markdown]
# #  The Deterministic Cake Eating Problem - Endogenous Grid Method Solution
# ### by [Jason DeBacker](http://jasondebacker.com), June 2018
# This Jupyter notebook illustrates how to solve the deterministic cake eating problem using Carroll's (2006) endogenous grid method (EGM).
#
# ## The Problem:
#
# $$V(w)=\max_{c} u(c)+\beta V(w'), \forall w\in[0,\bar{w}]$$
#
# The necessary condition (after applying the envelope theorem) is given by the Euler equation:
#
# $$ u'(c) = \beta u'(c') $$
#
# The unknowns in this system are functions: The value function, $V(w)$, and the policy function, $c = \phi(w)$ (or, equivalently, $w' = p(w)$).
#
# ## The Solution:
#
# We'll solve this problem using policy function iteration with the endogenous grid method.  With this method, we'll use an iterative procedure to converge to a fixed point in function space, the true policy function, $\phi(w)$, but we'll do some without the use of a minimizer or root-finder.  Another significant difference between EGM and standard PFI is that we'll choose a grid of $w'$ (and not $w$).
#
# The computational algorithm for EGM is as follows:
#
# 1. Create a discrete grid of the state variable, $w'$
# 2. Make an initial guess at the policy function, $\phi_{0}(w)$
#     * This will a function that returns a consumption value for any $w$
# 3. Solve for $c$ for each point on the grid of $w'$ using the Euler equation:
# $$ c = u^{'-1}\left(\beta u'(\phi_{0}(w'))\right)$$
# 4. Find the grid of $w$:
#     $$w = w' + c$$
# 5. Using the grid for $w$, update the guess at the policy function: $\phi_{1}(w) = K\phi(w) = c $ (this is the $c$ solved for in step 3).
# 5. Repeat this process:
# $$\phi_{i+1} \ (w) = K\phi(w) = c$$
# 6. Stop when, $|\phi_{i+1} \ (w)-\phi_{i}(w)|<\varepsilon$, where $\varepsilon$ is a small number.

# %%
# Import packages
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt
from scipy import interpolate

# to print plots inline
# %matplotlib inline

# %% [markdown]
# ## Step 1: Set parameters and create grid for state space
#
# Parameters:
# * $\beta$ = rate of time preference
# * $\sigma$ = coefficient of relative risk aversion (if $\sigma = 1$, $u(c)=log(c)$), parameter describes the curvature of the utility function

# %%
beta = 0.95
sigma = 1.0
R = 1

'''
------------------------------------------------------------------------
Create Grid for State Space    
------------------------------------------------------------------------
lb_w      = scalar, lower bound of cake grid
ub_w      = scalar, upper bound of cake grid 
size_w    = integer, number of grid points in cake state space
w_grid    = vector, size_w x 1 vector of cake grid points 
------------------------------------------------------------------------
'''
lb_w = 0.4 
ub_w = 2.0 
size_w = 200  # Number of grid points
w_grid = np.linspace(lb_w, ub_w, size_w)

# %% [markdown]
# ## Step 2: Create functions to use in solution

# %%
def utility_c(C, sigma):
    if sigma == 1:
        U = np.log(C)
    else:
        U = (C ** (1 - sigma)) / (1 - sigma)
    
    return U


def u_prime(C, sigma):
    try:
        # replace 0 and negative consumption with a tiny value
        # to impose non-negativity on cons
        C[C<=0] = 1e-10 
    except TypeError:
        if C <= 0:
            C = 1e-10
    MU = C ** - sigma
    
    return MU


def u_prime_inv(C, sigma):
    try:
        # replace 0 and negative consumption with a tiny value
        # to impose non-negativity on cons
        C[C<=0] = 1e-10 
    except TypeError:
        if C <= 0:
            C = 1e-10
    MU = C ** (- 1 / sigma)
    
    return MU

# %%
def coleman_egm(phi, w_prime_grid, params):
    '''
    The Coleman-Endogenous Grid Method operator, which takes an
    existing guess phi of the optimal consumption policy and computes and
    returns the updated function Kphi on the endogenous grid points.
    '''
    beta, sigma = params
    
    # == Initialize c == #
    c = np.empty_like(w_prime_grid)

    # == solve for updated consumption value == #
    for i, w_prime in enumerate(w_prime_grid):
        c[i] = u_prime_inv(beta * u_prime(phi(w_prime), sigma), sigma)
    
    # == Determine endogenous grid == #
    w_grid = w_prime_grid / R + c
    
    # == Update policy function == #
    Kphi = interpolate.interp1d(w_grid, c, kind='linear', fill_value='extrapolate')
    return Kphi

# %% [markdown]
# ## Step 3: Policy Function Iteration with EGM

# %%
'''
------------------------------------------------------------------------
Policy Function Iteration with Endogenous Grid Method
------------------------------------------------------------------------
PFtol     = scalar, tolerance required for policy function to converge
PFdist    = scalar, distance between last two policy functions
PFmaxiter = integer, maximum number of iterations for policy function
phi       = function, policy function for choice of consumption at each iteration
PFstore   = matrix, stores phi at each iteration 
PFiter    = integer, current iteration number
PF_params = tuple, contains parameters to pass into Coleman operator: beta, sigma
new_phi   = vector, updated policy function after applying Coleman operator 
------------------------------------------------------------------------
'''
PFtol = 1e-8 
PFdist = 7.0 
PFmaxiter = 500 
phi = lambda x:  x # initial guess at policy function is to eat all cake
PFstore = np.zeros((size_w, PFmaxiter)) #initialize PFstore array
PFiter = 1 
PF_params = (beta, sigma)
while PFdist > PFtol and PFiter < PFmaxiter:
    PFstore[:, PFiter] = phi(w_grid)
    new_phi= coleman_egm(phi, w_grid, PF_params)
    PFdist = (np.absolute(phi(w_grid) - new_phi(w_grid))).max()
    phi = new_phi
    PFiter += 1
    print('Iteration ', PFiter, ' distance = ', PFdist)

if PFiter < PFmaxiter:
    print('Policy function converged after this many iterations:', PFiter)
else:
    print('Policy function did not converge')
# Out:
# Iteration  2  distance =  0.987177379236
# Iteration  3  distance =  0.328986992004
# Iteration  4  distance =  0.164439412984
# Iteration  5  distance =  0.0986204012881
# Iteration  6  distance =  0.0657109167621
# Iteration  7  distance =  0.0469055193524
# Iteration  8  distance =  0.0351521690301
# Iteration  9  distance =  0.0273166257727
# Iteration  10  distance =  0.0218317695589
# Iteration  11  distance =  0.0178428076397
# Iteration  12  distance =  0.0148511109011
# Iteration  13  distance =  0.0125498306468
# Iteration  14  distance =  0.01074170699
# Iteration  15  distance =  0.00929523332852
# Iteration  16  distance =  0.0081199988624
# Iteration  17  distance =  0.00715218419239
# Iteration  18  distance =  0.00634569751906
# Iteration  19  distance =  0.00566657645272
# Iteration  20  distance =  0.00508934918995
# Iteration  21  distance =  0.00459460863125
# Iteration  22  distance =  0.00416735837036
# Iteration  23  distance =  0.00379586207816
# Iteration  24  distance =  0.00347082848294
# Iteration  25  distance =  0.00318482455621
# Iteration  26  distance =  0.0029318466869
# Iteration  27  distance =  0.00270700303271
# Iteration  28  distance =  0.0025062752836
# Iteration  29  distance =  0.00232633793061
# Iteration  30  distance =  0.00216441970538
# Iteration  31  distance =  0.00201819630745
# Iteration  32  distance =  0.00188570659752
# Iteration  33  distance =  0.0017652865679
# Iteration  34  distance =  0.00165551690727
# Iteration  35  distance =  0.00155518105252
# Iteration  36  distance =  0.00146323139716
# Iteration  37  distance =  0.00137876189275
# Iteration  38  distance =  0.00130098569748
# Iteration  39  distance =  0.00122921683647
# Iteration  40  distance =  0.00116285507163
# Iteration  41  distance =  0.00110137335462
# Iteration  42  distance =  0.00104430737107
# Iteration  43  distance =  0.000991246786856
# Iteration  44  distance =  0.000941827887068
# Iteration  45  distance =  0.000895727359997
# Iteration  46  distance =  0.000852657027064
# Iteration  47  distance =  0.000812359357653
# Iteration  48  distance =  0.000774603638044
# Iteration  49  distance =  0.000739182687639
# Iteration  50  distance =  0.000705910034933
# Iteration  51  distance =  0.000674617481094
# Iteration  52  distance =  0.000645152991534
# Iteration  53  distance =  0.000617378865959
# Iteration  54  distance =  0.000591170145634
# Iteration  55  distance =  0.000566413223376
# Iteration  56  distance =  0.000543004627292
# Iteration  57  distance =  0.000520849953895
# Iteration  58  distance =  0.000499862929987
# Iteration  59  distance =  0.000479964585846
# Iteration  60  distance =  0.000461082524882
# Iteration  61  distance =  0.000443150277108
# Iteration  62  distance =  0.000426106725606
# Iteration  63  distance =  0.000409895596731
# Iteration  64  distance =  0.000394465006076
# Iteration  65  distance =  0.000379767053329
# Iteration  66  distance =  0.000365757460118
# Iteration  67  distance =  0.000352395245688
# Iteration  68  distance =  0.000339642435966
# Iteration  69  distance =  0.000327463802153
# Iteration  70  distance =  0.000315826625453
# Iteration  71  distance =  0.000304700485004
# Iteration  72  distance =  0.000294057066432
# Iteration  73  distance =  0.000283869988761
# Iteration  74  distance =  0.000274114647704
# Iteration  75  distance =  0.000264768073579
# Iteration  76  distance =  0.000255808802319
# Iteration  77  distance =  0.000247216758205
# Iteration  78  distance =  0.000238973147132
# Iteration  79  distance =  0.000231060359329
# Iteration  80  distance =  0.000223461880596
# Iteration  81  distance =  0.000216162211213
# Iteration  82  distance =  0.000209146791777
# Iteration  83  distance =  0.000202401935287
# Iteration  84  distance =  0.0001959147649
# Iteration  85  distance =  0.000189673156808
# Iteration  86  distance =  0.000183665687769
# Iteration  87  distance =  0.000177881586858
# Iteration  88  distance =  0.000172310691066
# Iteration  89  distance =  0.000166943404378
# Iteration  90  distance =  0.000161770660048
# Iteration  91  distance =  0.00015678388577
# Iteration  92  distance =  0.000151974971502
# Iteration  93  distance =  0.000147336239713
# Iteration  94  distance =  0.000142860417846
# Iteration  95  distance =  0.00013854061281
# Iteration  96  distance =  0.000134370287334
# Iteration  97  distance =  0.000130343238025
# Iteration  98  distance =  0.000126453574999
# Iteration  99  distance =  0.000122695702949
# Iteration  100  distance =  0.000119064303536
# Iteration  101  distance =  0.000115554319007
# Iteration  102  distance =  0.000112160936933
# Iteration  103  distance =  0.000108879575987
# Iteration  104  distance =  0.000105705872673
# Iteration  105  distance =  0.000102635668953
# Iteration  106  distance =  9.96650006735e-05
# Iteration  107  distance =  9.67900867663e-05
# Iteration  108  distance =  9.40073191355e-05
# Iteration  109  distance =  9.13132532021e-05
# Iteration  110  distance =  8.87045990467e-05
# Iteration  111  distance =  8.61782131111e-05
# Iteration  112  distance =  8.37310904187e-05
# Iteration  113  distance =  8.13603572758e-05
# Iteration  114  distance =  7.90632644211e-05
# Iteration  115  distance =  7.68371805922e-05
# Iteration  116  distance =  7.46795864787e-05
# Iteration  117  distance =  7.25880690381e-05
# Iteration  118  distance =  7.0560316147e-05
# Iteration  119  distance =  6.85941115679e-05
# Iteration  120  distance =  6.66873302074e-05
# Iteration  121  distance =  6.48379336499e-05
# Iteration  122  distance =  6.30439659454e-05
# Iteration  123  distance =  6.13035496377e-05
# Iteration  124  distance =  5.96148820155e-05
# Iteration  125  distance =  5.79762315727e-05
# Iteration  126  distance =  5.63859346657e-05
# Iteration  127  distance =  5.48423923528e-05
# Iteration  128  distance =  5.3344067407e-05
# Iteration  129  distance =  5.18894814898e-05
# Iteration  130  distance =  5.04772124764e-05
# Iteration  131  distance =  4.91058919233e-05
# Iteration  132  distance =  4.77742026694e-05
# Iteration  133  distance =  4.64808765626e-05
# Iteration  134  distance =  4.52246923046e-05
# Iteration  135  distance =  4.4004473407e-05
# Iteration  136  distance =  4.2819086251e-05
# Iteration  137  distance =  4.16674382466e-05
# Iteration  138  distance =  4.05484760836e-05
# Iteration  139  distance =  3.94611840706e-05
# Iteration  140  distance =  3.84045825559e-05
# Iteration  141  distance =  3.73777264266e-05
# Iteration  142  distance =  3.63797036799e-05
# Iteration  143  distance =  3.5409634065e-05
# Iteration  144  distance =  3.44666677896e-05
# Iteration  145  distance =  3.3549984288e-05
# Iteration  146  distance =  3.26587910479e-05
# Iteration  147  distance =  3.17923224923e-05
# Iteration  148  distance =  3.09498389137e-05
# Iteration  149  distance =  3.0130625457e-05
# Iteration  150  distance =  2.93339911509e-05
# Iteration  151  distance =  2.85592679811e-05
# Iteration  152  distance =  2.78058100079e-05
# Iteration  153  distance =  2.70729925218e-05
# Iteration  154  distance =  2.63602112379e-05
# Iteration  155  distance =  2.56668815255e-05
# Iteration  156  distance =  2.49924376717e-05
# Iteration  157  distance =  2.43363321777e-05
# Iteration  158  distance =  2.36980350852e-05
# Iteration  159  distance =  2.30770333316e-05
# Iteration  160  distance =  2.24728301337e-05
# Iteration  161  distance =  2.1884944397e-05
# Iteration  162  distance =  2.13129101501e-05
# Iteration  163  distance =  2.07562760027e-05
# Iteration  164  distance =  2.02146046265e-05
# Iteration  165  distance =  1.96874722573e-05
# Iteration  166  distance =  1.91744682181e-05
# Iteration  167  distance =  1.86751944607e-05
# Iteration  168  distance =  1.81892651269e-05
# Iteration  169  distance =  1.77163061268e-05
# Iteration  170  distance =  1.72559547342e-05
# Iteration  171  distance =  1.68078591984e-05
# Iteration  172  distance =  1.63716783702e-05
# Iteration  173  distance =  1.59470813444e-05
# Iteration  174  distance =  1.55337471143e-05
# Iteration  175  distance =  1.51313642414e-05
# Iteration  176  distance =  1.47396305364e-05
# Iteration  177  distance =  1.4358252753e-05
# Iteration  178  distance =  1.39869462937e-05
# Iteration  179  distance =  1.3625434926e-05
# Iteration  180  distance =  1.32734505096e-05
# Iteration  181  distance =  1.29307327342e-05
# Iteration  182  distance =  1.25970288662e-05
# Iteration  183  distance =  1.22720935054e-05
# Iteration  184  distance =  1.19556883505e-05
# Iteration  185  distance =  1.16475819726e-05
# Iteration  186  distance =  1.1347549598e-05
# Iteration  187  distance =  1.10553728979e-05
# Iteration  188  distance =  1.07708397855e-05
# Iteration  189  distance =  1.04937442216e-05
# Iteration  190  distance =  1.02238860257e-05
# Iteration  191  distance =  9.96107069434e-06
# Iteration  192  distance =  9.70510922589e-06
# Iteration  193  distance =  9.45581795127e-06
# Iteration  194  distance =  9.21301837047e-06
# Iteration  195  distance =  8.97653699506e-06
# Iteration  196  distance =  8.74620519556e-06
# Iteration  197  distance =  8.52185905457e-06
# Iteration  198  distance =  8.30333922445e-06
# Iteration  199  distance =  8.09049078995e-06
# Iteration  200  distance =  7.88316313568e-06
# Iteration  201  distance =  7.68120981747e-06
# Iteration  202  distance =  7.48448843876e-06
# Iteration  203  distance =  7.29286053008e-06
# Iteration  204  distance =  7.10619143376e-06
# Iteration  205  distance =  6.92435019108e-06
# Iteration  206  distance =  6.74720943413e-06
# Iteration  207  distance =  6.57464528071e-06
# Iteration  208  distance =  6.40653723254e-06
# Iteration  209  distance =  6.24276807724e-06
# Iteration  210  distance =  6.08322379277e-06
# Iteration  211  distance =  5.92779345533e-06
# Iteration  212  distance =  5.77636915033e-06
# Iteration  213  distance =  5.62884588572e-06
# Iteration  214  distance =  5.48512150832e-06
# Iteration  215  distance =  5.34509662288e-06
# Iteration  216  distance =  5.20867451306e-06
# Iteration  217  distance =  5.07576106601e-06
# Iteration  218  distance =  4.94626469797e-06
# Iteration  219  distance =  4.820096283e-06
# Iteration  220  distance =  4.69716908377e-06
# Iteration  221  distance =  4.57739868426e-06
# Iteration  222  distance =  4.46070292454e-06
# Iteration  223  distance =  4.3470018378e-06
# Iteration  224  distance =  4.23621758898e-06
# Iteration  225  distance =  4.12827441525e-06
# Iteration  226  distance =  4.02309856858e-06
# Iteration  227  distance =  3.92061825982e-06
# Iteration  228  distance =  3.82076360416e-06
# Iteration  229  distance =  3.723466569e-06
# Iteration  230  distance =  3.62866092233e-06
# Iteration  231  distance =  3.53628218364e-06
# Iteration  232  distance =  3.44626757551e-06
# Iteration  233  distance =  3.35855597705e-06
# Iteration  234  distance =  3.27308787841e-06
# Iteration  235  distance =  3.1898053371e-06
# Iteration  236  distance =  3.10865193476e-06
# Iteration  237  distance =  3.02957273623e-06
# Iteration  238  distance =  2.95251424864e-06
# Iteration  239  distance =  2.87742438296e-06
# Iteration  240  distance =  2.80425241529e-06
# Iteration  241  distance =  2.73294895041e-06
# Iteration  242  distance =  2.66346588572e-06
# Iteration  243  distance =  2.59575637655e-06
# Iteration  244  distance =  2.52977480199e-06
# Iteration  245  distance =  2.46547673226e-06
# Iteration  246  distance =  2.40281889672e-06
# Iteration  247  distance =  2.34175915264e-06
# Iteration  248  distance =  2.28225645518e-06
# Iteration  249  distance =  2.22427082792e-06
# Iteration  250  distance =  2.16776333439e-06
# Iteration  251  distance =  2.11269605031e-06
# Iteration  252  distance =  2.05903203673e-06
# Iteration  253  distance =  2.00673531364e-06
# Iteration  254  distance =  1.95577083464e-06
# Iteration  255  distance =  1.90610446224e-06
# Iteration  256  distance =  1.8577029434e-06
# Iteration  257  distance =  1.81053388663e-06
# Iteration  258  distance =  1.76456573875e-06
# Iteration  259  distance =  1.71976776299e-06
# Iteration  260  distance =  1.67611001741e-06
# Iteration  261  distance =  1.6335633339e-06
# Iteration  262  distance =  1.59209929774e-06
# Iteration  263  distance =  1.55169022796e-06
# Iteration  264  distance =  1.51230915783e-06
# Iteration  265  distance =  1.47392981618e-06
# Iteration  266  distance =  1.43652660934e-06
# Iteration  267  distance =  1.40007460304e-06
# Iteration  268  distance =  1.36454950529e-06
# Iteration  269  distance =  1.3299276497e-06
# Iteration  270  distance =  1.29618597886e-06
# Iteration  271  distance =  1.26330202863e-06
# Iteration  272  distance =  1.23125391254e-06
# Iteration  273  distance =  1.20002030687e-06
# Iteration  274  distance =  1.16958043557e-06
# Iteration  275  distance =  1.13991405657e-06
# Iteration  276  distance =  1.11100144749e-06
# Iteration  277  distance =  1.08282339206e-06
# Iteration  278  distance =  1.05536116733e-06
# Iteration  279  distance =  1.02859653053e-06
# Iteration  280  distance =  1.00251170665e-06
# Iteration  281  distance =  9.7708937645e-07
# Iteration  282  distance =  9.52312664476e-07
# Iteration  283  distance =  9.2816512761e-07
# Iteration  284  distance =  9.04630743891e-07
# Iteration  285  distance =  8.81693901666e-07
# Iteration  286  distance =  8.5933938878e-07
# Iteration  287  distance =  8.37552382504e-07
# Iteration  288  distance =  8.16318439165e-07
# Iteration  289  distance =  7.95623484692e-07
# Iteration  290  distance =  7.75453804835e-07
# Iteration  291  distance =  7.55796035853e-07
# Iteration  292  distance =  7.36637155684e-07
# Iteration  293  distance =  7.17964474962e-07
# Iteration  294  distance =  6.99765628484e-07
# Iteration  295  distance =  6.8202856679e-07
# Iteration  296  distance =  6.64741548355e-07
# Iteration  297  distance =  6.47893131055e-07
# Iteration  298  distance =  6.314721651e-07
# Iteration  299  distance =  6.15467785188e-07
# Iteration  300  distance =  5.99869403067e-07
# Iteration  301  distance =  5.84666700831e-07
# Iteration  302  distance =  5.69849623488e-07
# Iteration  303  distance =  5.55408372661e-07
# Iteration  304  distance =  5.41333399676e-07
# Iteration  305  distance =  5.27615399253e-07
# Iteration  306  distance =  5.14245303326e-07
# Iteration  307  distance =  5.01214274848e-07
# Iteration  308  distance =  4.88513702032e-07
# Iteration  309  distance =  4.76135192301e-07
# Iteration  310  distance =  4.64070567106e-07
# Iteration  311  distance =  4.52311855845e-07
# Iteration  312  distance =  4.40851291125e-07
# Iteration  313  distance =  4.29681303218e-07
# Iteration  314  distance =  4.18794515081e-07
# Iteration  315  distance =  4.0818373747e-07
# Iteration  316  distance =  3.97841964123e-07
# Iteration  317  distance =  3.87762366931e-07
# Iteration  318  distance =  3.77938291697e-07
# Iteration  319  distance =  3.6836325331e-07
# Iteration  320  distance =  3.59030931839e-07
# Iteration  321  distance =  3.49935167898e-07
# Iteration  322  distance =  3.4106995879e-07
# Iteration  323  distance =  3.32429454561e-07
# Iteration  324  distance =  3.24007953821e-07
# Iteration  325  distance =  3.15799900306e-07
# Iteration  326  distance =  3.07799878842e-07
# Iteration  327  distance =  3.00002611989e-07
# Iteration  328  distance =  2.92402956396e-07
# Iteration  329  distance =  2.84995899436e-07
# Iteration  330  distance =  2.7777655582e-07
# Iteration  331  distance =  2.70740164413e-07
# Iteration  332  distance =  2.63882085107e-07
# Iteration  333  distance =  2.57197795527e-07
# Iteration  334  distance =  2.50682888246e-07
# Iteration  335  distance =  2.44333067841e-07
# Iteration  336  distance =  2.38144147915e-07
# Iteration  337  distance =  2.32112048401e-07
# Iteration  338  distance =  2.26232792847e-07
# Iteration  339  distance =  2.20502505692e-07
# Iteration  340  distance =  2.14917409973e-07
# Iteration  341  distance =  2.09473824439e-07
# Iteration  342  distance =  2.04168161336e-07
# Iteration  343  distance =  1.98996923953e-07
# Iteration  344  distance =  1.93956704565e-07
# Iteration  345  distance =  1.89044181573e-07
# Iteration  346  distance =  1.8425611794e-07
# Iteration  347  distance =  1.79589358669e-07
# Iteration  348  distance =  1.75040828956e-07
# Iteration  349  distance =  1.70607531824e-07
# Iteration  350  distance =  1.66286546574e-07
# Iteration  351  distance =  1.62075026393e-07
# Iteration  352  distance =  1.57970196847e-07
# Iteration  353  distance =  1.53969353801e-07
# Iteration  354  distance =  1.50069861801e-07
# Iteration  355  distance =  1.46269152214e-07
# Iteration  356  distance =  1.42564721528e-07
# Iteration  357  distance =  1.38954129772e-07
# Iteration  358  distance =  1.35434998862e-07
# Iteration  359  distance =  1.32005011047e-07
# Iteration  360  distance =  1.28661907302e-07
# Iteration  361  distance =  1.25403485984e-07
# Iteration  362  distance =  1.22227601158e-07
# Iteration  363  distance =  1.19132161427e-07
# Iteration  364  distance =  1.16115128408e-07
# Iteration  365  distance =  1.13174515287e-07
# Iteration  366  distance =  1.10308385801e-07
# Iteration  367  distance =  1.07514852674e-07
# Iteration  368  distance =  1.04792076516e-07
# Iteration  369  distance =  1.02138264534e-07
# Iteration  370  distance =  9.95516694774e-08
# Iteration  371  distance =  9.70305882725e-08
# Iteration  372  distance =  9.45733611216e-08
# Iteration  373  distance =  9.21783702076e-08
# Iteration  374  distance =  8.98440388405e-08
# Iteration  375  distance =  8.75688301663e-08
# Iteration  376  distance =  8.5351246501e-08
# Iteration  377  distance =  8.31898278111e-08
# Iteration  378  distance =  8.10831512904e-08
# Iteration  379  distance =  7.90298302217e-08
# Iteration  380  distance =  7.70285128321e-08
# Iteration  381  distance =  7.50778818698e-08
# Iteration  382  distance =  7.31766532092e-08
# Iteration  383  distance =  7.13235754624e-08
# Iteration  384  distance =  6.95174288898e-08
# Iteration  385  distance =  6.77570246022e-08
# Iteration  386  distance =  6.60412039291e-08
# Iteration  387  distance =  6.43688375518e-08
# Iteration  388  distance =  6.27388247257e-08
# Iteration  389  distance =  6.11500926076e-08
# Iteration  390  distance =  5.96015955964e-08
# Iteration  391  distance =  5.8092314438e-08
# Iteration  392  distance =  5.66212559755e-08
# Iteration  393  distance =  5.51874518862e-08
# Iteration  394  distance =  5.37899586817e-08
# Iteration  395  distance =  5.24278565214e-08
# Iteration  396  distance =  5.11002490738e-08
# Iteration  397  distance =  4.98062626419e-08
# Iteration  398  distance =  4.85450456431e-08
# Iteration  399  distance =  4.73157680606e-08
# Iteration  400  distance =  4.6117620979e-08
# Iteration  401  distance =  4.49498158903e-08
# Iteration  402  distance =  4.38115843326e-08
# Iteration  403  distance =  4.2702177315e-08
# Iteration  404  distance =  4.16208647269e-08
# Iteration  405  distance =  4.0566935075e-08
# Iteration  406  distance =  3.95396947822e-08
# Iteration  407  distance =  3.85384678961e-08
# Iteration  408  distance =  3.75625957005e-08
# Iteration  409  distance =  3.66114358621e-08
# Iteration  410  distance =  3.56843627147e-08
# Iteration  411  distance =  3.4780766052e-08
# Iteration  412  distance =  3.39000514049e-08
# Iteration  413  distance =  3.30416392719e-08
# Iteration  414  distance =  3.22049647783e-08
# Iteration  415  distance =  3.13894774409e-08
# Iteration  416  distance =  3.05946406751e-08
# Iteration  417  distance =  2.98199314963e-08
# Iteration  418  distance =  2.90648401666e-08
# Iteration  419  distance =  2.83288698819e-08
# Iteration  420  distance =  2.76115363559e-08
# Iteration  421  distance =  2.69123676816e-08
# Iteration  422  distance =  2.62309037893e-08
# Iteration  423  distance =  2.55666963017e-08
# Iteration  424  distance =  2.49193082766e-08
# Iteration  425  distance =  2.42883136797e-08
# Iteration  426  distance =  2.36732974196e-08
# Iteration  427  distance =  2.30738548546e-08
# Iteration  428  distance =  2.24895915571e-08
# Iteration  429  distance =  2.1920123168e-08
# Iteration  430  distance =  2.13650749939e-08
# Iteration  431  distance =  2.08240818755e-08
# Iteration  432  distance =  2.02967878546e-08
# Iteration  433  distance =  1.97828460349e-08
# Iteration  434  distance =  1.9281918312e-08
# Iteration  435  distance =  1.87936751161e-08
# Iteration  436  distance =  1.83177952112e-08
# Iteration  437  distance =  1.78539655213e-08
# Iteration  438  distance =  1.74018809085e-08
# Iteration  439  distance =  1.69612439302e-08
# Iteration  440  distance =  1.65317647141e-08
# Iteration  441  distance =  1.61131606807e-08
# Iteration  442  distance =  1.57051565017e-08
# Iteration  443  distance =  1.53074836556e-08
# Iteration  444  distance =  1.49198806157e-08
# Iteration  445  distance =  1.45420923428e-08
# Iteration  446  distance =  1.41738703066e-08
# Iteration  447  distance =  1.38149722426e-08
# Iteration  448  distance =  1.34651620895e-08
# Iteration  449  distance =  1.31242097051e-08
# Iteration  450  distance =  1.27918906995e-08
# Iteration  451  distance =  1.24679866223e-08
# Iteration  452  distance =  1.21522841998e-08
# Iteration  453  distance =  1.18445759104e-08
# Iteration  454  distance =  1.15446592078e-08
# Iteration  455  distance =  1.1252336854e-08
# Iteration  456  distance =  1.09674164889e-08
# Iteration  457  distance =  1.06897107277e-08
# Iteration  458  distance =  1.04190368763e-08
# Iteration  459  distance =  1.01552168688e-08
# Iteration  460  distance =  9.89807707324e-09
# Policy function converged after this many iterations: 460

# %% [markdown]
# ## Step 4: Extract decision rules from solution

# %%
'''
------------------------------------------------------------------------
Find savings policy function and value function   
------------------------------------------------------------------------
optC  = vector, the optimal choice of c for each c
optW  = vector, the optimal choice of w' for each w
VF    = vector, the "true" value function
------------------------------------------------------------------------
'''
optC = phi(w_grid) # optimal consumption
optW = R * (w_grid - optC) # solution to the savings policy function from transition equation
# Out:
# -3.72886427822
# -10.1172310024
# -18.8898277673
# -29.7922606519
# -42.5896145526
# -57.0651412868
# -73.0190302154
# -90.2672568607
# -108.640512106
# -127.983391514
# VF iter =  10

# %% [markdown]
# ## Visualize output

# %%
#Plot optimal consumption rule as a function of cake size
plt.figure()
fig, ax = plt.subplots()
ax.plot(w_grid[1:], optC[1:], label='Consumption')
# Now add the legend with some customizations.
legend = ax.legend(loc='upper left', shadow=False)
# Set the fontsize
for label in legend.get_texts():
    label.set_fontsize('large')
for label in legend.get_lines():
    label.set_linewidth(1.5)  # the legend line width
plt.xlabel('Size of Cake')
plt.ylabel('Optimal Consumption')
plt.title('Policy Function, consumption - deterministic cake eating')
plt.show()

# %%
#Plot cake to leave rule as a function of cake size
plt.figure()
fig, ax = plt.subplots()
ax.plot(w_grid[1:], optW[1:], label='Savings')
ax.plot(w_grid[1:], w_grid[1:], '--', label='45 degree line')
# Now add the legend with some customizations.
legend = ax.legend(loc='upper left', shadow=False)
# Set the fontsize
for label in legend.get_texts():
    label.set_fontsize('large')
for label in legend.get_lines():
    label.set_linewidth(1.5)  # the legend line width
plt.xlabel('Size of Cake')
plt.ylabel('Optimal Savings')
plt.title('Policy Function, savings - deterministic cake eating')
plt.show()

# %% [markdown]
# ## Finding approximation errors
#
# It's a little complicated (we need to do the guess and verify method), but we can show that with $\sigma = 1.0$ (i.e., $u(c) = log(c)$), then the policy function is $w' = \beta w$.  Knowing this, we can find the approximation error from our solution method (VFI over a discrete grid).  This errors are found as:

# %%
Wprime_errors = optW - beta * w_grid

# Plot policy function approximation errors
plt.figure()
plt.plot(w_grid[1:], Wprime_errors[1:])
plt.xlabel('Size of Cake')
plt.ylabel('Error')
plt.title('VFI w prime policy function errors')
plt.show()

# %%
C_errors = optC - (1 - beta) * w_grid
# Plot policy function approximation errors
plt.figure()
plt.plot(w_grid[1:], C_errors[1:])
plt.xlabel('Size of Cake')
plt.ylabel('Error')
plt.title('VFI consumption policy function errors')
plt.show()
